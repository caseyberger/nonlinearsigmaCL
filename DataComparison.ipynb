# %% [markdown]
# # Check results from two different runs

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from LatticeData import *

# %% [markdown]
# Speedup = time_old/time_new

# %%
#v1 = LatticeData(datadir = "/data_opt_no_omp/")
#v1 = LatticeData(datadir = "/data_Q_test/")
v1 = LatticeData(datadir = "/data_omptest2/")
v2 = LatticeData(datadir = "/data_ompQtest/")

# %%
df_old = v1.do_stats(therm = 0.4)
len_mask = df_old.index.get_level_values('length') < 20 
nMC_mask = df_old.index.get_level_values('nMC') == 10000
ntherm_mask = df_old.index.get_level_values('ntherm') == 0
df_old = df_old[len_mask & nMC_mask & nMC_mask]
#df_old = df_old.dropna()
df_new = v2.do_stats(therm = 0.4)

# %%
df_old.columns = pd.MultiIndex.from_product([df_old.columns, ['v1']])
df_new.columns = pd.MultiIndex.from_product([df_new.columns, ['v2']])

# %%
df_all = pd.concat([df_old,df_new])
df_all = df_all.stack()
df_all.index.set_names('version', level=len(df_all.index.names)-1, inplace=True)

# %%
sns.scatterplot(data = df_all, x = "length", y = "time (hr)", hue = "version", 
                alpha = 0.75, palette = "viridis")
#plt.yscale('log')
plt.show()

# %% [markdown]
# # Check Observables

# %%
sns.relplot(data = df_all, x = "itheta", y = "Q_L_mean", hue = "version", 
                row = "length", alpha = 0.75, palette = "inferno")
#plt.yscale('log')
plt.show()

# %%
sns.relplot(data = df_all, x = "itheta", y = "A_L_mean", hue = "version", 
                row = "length",alpha = 0.75, palette = "viridis")
#plt.yscale('log')
plt.show()

# %%
sns.relplot(data = df_all, x = "itheta", y = "Xi_L_mean", hue = "version", 
                row = "length", alpha = 0.75, palette = "viridis")
#plt.yscale('log')
plt.show()

# %%
sns.relplot(data = df_all, x = "itheta", y = "corr_length_mean", hue = "version", 
                row = "length", alpha = 0.75, palette = "viridis")
#plt.yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1866471/297666368.py in <module>
# ----> 1 sns.relplot(data = df_all, x = "itheta", y = "corr_length_mean", hue = "version",
#       2                 row = "length", alpha = 0.75, palette = "viridis")
#       3 #plt.yscale('log')
#       4 plt.show()
#
# /opt/jupyterhub/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/jupyterhub/lib/python3.8/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     945
#     946     # Use the full dataset to map the semantics
# --> 947     p = plotter(
#     948         data=data,
#     949         variables=plotter.get_semantics(locals()),
#
# /opt/jupyterhub/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# /opt/jupyterhub/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# /opt/jupyterhub/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# /opt/jupyterhub/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `corr_length_mean` for parameter `y`
